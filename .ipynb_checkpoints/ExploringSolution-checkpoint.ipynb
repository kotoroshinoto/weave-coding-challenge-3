# %% [markdown]
# # 1. Handle single step queries e.g.
# - [x] "What are the targets of vorinostat?"
# - [x] "Find drugs that are used for treating ulcerative colitis." etc.
# # 2. Handle 2-step queries e.g.
# - [x] "Which diseases are associated with the genes targetted by fasudil?"
# - [ ] "Show all the diseases that have at least 5 pathways associated with Alzheimer"
#   - NOTE: I do not think graphql supports carrying this out in a single operation given the open targets schema does not provide any resolvers or function/field to enable us to link pathways back to targets or to count entities based on this association from disease->gene->pathway and use that aggregation as part of a filter. This could be carried out as a multi-query by the client, but that seems to be beyond the intended scope of this exercise. Implementing that with natural human language interpretation by GPT would likely also require us to ask gpt to help us write code to interpret the results of a possibly infinite number of asks that cannot be fulfilled by the current open targets schema in a single query, and somehow ensuring that executing that functionality in the current python session would work correctly. Implementing something like that would take a bit longer than I think this task was intended to take, so I am going to leave this particular feature unimplemented, and make sure the script has the capacity to report when the constructed queries cause an error (as this one does).

# %%
import os
import sys
import re
import json
import requests
import openai
from datetime import datetime
from utils import extract_values
from urlpath import URL

# %%
opentargets_base_url = "https://api.platform.opentargets.org/api/v4/graphql"
open_targets_base = URL(opentargets_base_url)
open_targets_schema_url = open_targets_base / "schema"
schema_response = open_targets_schema_url.get()
open_targets_schema = schema_response.content.decode()

# %%
openai.api_key = os.environ.get("OPENAI_API_KEY")

# %%
models = openai.Model.list()
model_ids = []
for item in models['data']:
    model_ids.append(item['id'])
sorted(model_ids)

# %%
# gpt_model = 'gpt-3.5-turbo-16k'
gpt_model = 'gpt-4'

# %%
# Open Targets graphQL schema example
# read from file
with open("graphql_schema.txt", "r") as f:
    prompt_templates = f.read()

# %%
def generate_query_for_opentargets_using_human_language(user_input):
    completion_prompt = "\nGiven this schema, what resources would be required to retrieve the results of this query: "
    resource_messages = [{'role':'user', 'content': "The following is the schema provided by Open Targets for their graphQL API:\n" + open_targets_schema + "\n\n" + completion_prompt + user_input}]
    resource_response = openai.ChatCompletion.create(
        model=gpt_model,
        messages=resource_messages,
        temperature=0,
        max_tokens=250,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0,
        stop=["###"],
    )
    resource_response_message = resource_response['choices'][0]['message']
    graphql_messages = [
        {
            'role':'user',
            'content': resource_response_message['content']
        },
        {
            'role':'user',
            'content': 'Here are some example queries: \n' + prompt_templates
        },
        {
        'role':'user',
        'content': 'Please do not include extra variables not in the examples. Do not tranform or translate any drug, disease or gene names into chemblId, EFO ID, or ENSEMBL ID. Follow the examples strictly. Do not include extra variables in the query. Please use the resources listed and the example queries to generate a graphQL expression that fetches all the required data to complete the query: "' + user_input + "; query generated_query {\n  search("
        }
    ]
    graphql_response = openai.ChatCompletion.create(
        model=gpt_model,
        messages=graphql_messages,
        temperature=0,
        max_tokens=500,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0,
        stop=["###"],
    )
    return "query generated_query {\n  search(" + graphql_response['choices'][0]['message']['content']
def store_custom_query(user_input, query_string):
    query_file = "query_" + datetime.now().strftime("%Y_%m_%d-%I_%M_%S_%p") + ".txt"
    with open(query_file, "w") as f:
        f.write(f"# User input: {user_input}\n")
        f.write(query_string)
        #print(f"\nCustom graphQL query was written to file: {query_file}")
        
def perform_opentargets_query(query):
    # Perform POST request and check status code of response
    # This handles the cases where the Open Targets API is down or our query is invalid
    try:
        response = open_targets_base.post(json={"query": query})
        response.raise_for_status()
    except requests.exceptions.HTTPError as err:
        print(err, file=sys.stderr)
        print(response.content.decode(), file=sys.stderr)
        return None
    except:
        the_type, the_value, the_traceback = sys.exc_info()
        print("exception occurred: %s -> %s" % (str(the_type), str(the_value)), file=sys.stderr)
        return None
    
    return response.content.decode()

def test_input(user_input):
    test_result = generate_query_for_opentargets_using_human_language(user_input)
    store_custom_query(user_input, test_result)
    test_query_result = perform_opentargets_query(test_result)
    return test_result, test_query_result

# %%
test_cases = [
    "What are the targets of vorinostat?",
    "Find drugs that are used for treating ulcerative colitis.",
    "Which diseases are associated with the genes targeted by fasudil?",
    "What pathways are associated with breast cancer?",
    "Find the top 2 diseases associated with BRCA1",
    "Show all the diseases that have at least 5 pathways associated with Alzheimers"
]
test_results = []
test_query_results = []
for test_case in test_cases:
    test_result, test_query_result = test_input(test_case)
    test_results.append(test_result)
    test_query_results.append(test_query_result)
    print(test_result)
    print(test_query_result)
# Out:
# query generated_query {
#   search(queryString: "vorinostat", entityNames: "drug", page: {index: 0, size: 1}) {
#     hits {
#       id
#       name
#       entity
#       object {
#         ... on Drug {
#           mechanismsOfAction {
#             rows {
#               targets {
#                 id
#                 approvedSymbol
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }
# {"data":{"search":{"hits":[{"id":"CHEMBL98","name":"VORINOSTAT","entity":"drug","object":{"mechanismsOfAction":{"rows":[{"targets":[{"id":"ENSG00000171720","approvedSymbol":"HDAC3"}]},{"targets":[{"id":"ENSG00000094631","approvedSymbol":"HDAC6"}]},{"targets":[{"id":"ENSG00000116478","approvedSymbol":"HDAC1"}]},{"targets":[{"id":"ENSG00000196591","approvedSymbol":"HDAC2"}]}]}}}]}}}
# query generated_query {
#   search(queryString: "ulcerative colitis", entityNames: "disease", page: {index: 0, size: 1}) {
#     hits {
#       id
#       name
#       entity
#       object {
#         ... on Disease {
#           knownDrugs {
#             rows {
#               drugId
#               prefName
#             }
#           }
#         }
#       }
#     }
#   }
# }
# {"data":{"search":{"hits":[{"id":"EFO_0000729","name":"ulcerative colitis","entity":"disease","object":{"knownDrugs":{"rows":[{"drugId":"CHEMBL421","prefName":"SULFASALAZINE"},{"drugId":"CHEMBL1370","prefName":"BUDESONIDE"},{"drugId":"CHEMBL1433","prefName":"DOXYCYCLINE ANHYDROUS"},{"drugId":"CHEMBL1201580","prefName":"ADALIMUMAB"},{"drugId":"CHEMBL1433","prefName":"DOXYCYCLINE ANHYDROUS"},{"drugId":"CHEMBL1201833","prefName":"GOLIMUMAB"},{"drugId":"CHEMBL635","prefName":"PREDNISONE"},{"drugId":"CHEMBL1200699","prefName":"DOXYCYCLINE"},{"drugId":"CHEMBL1743087","prefName":"VEDOLIZUMAB"},{"drugId":"CHEMBL1201580","prefName":"ADALIMUMAB"},{"drugId":"CHEMBL650","prefName":"METHYLPREDNISOLONE"},{"drugId":"CHEMBL704","prefName":"MESALAMINE"},{"drugId":"CHEMBL1200762","prefName":"BETAMETHASONE SODIUM PHOSPHATE"},{"drugId":"CHEMBL704","prefName":"MESALAMINE"},{"drugId":"CHEMBL1201581","prefName":"INFLIXIMAB"},{"drugId":"CHEMBL421","prefName":"SULFASALAZINE"},{"drugId":"CHEMBL635","prefName":"PREDNISONE"},{"drugId":"CHEMBL704","prefName":"MESALAMINE"},{"drugId":"CHEMBL655","prefName":"MIDAZOLAM"},{"drugId":"CHEMBL704","prefName":"MESALAMINE"},{"drugId":"CHEMBL635","prefName":"PREDNISONE"},{"drugId":"CHEMBL1200699","prefName":"DOXYCYCLINE"},{"drugId":"CHEMBL1201346","prefName":"BALSALAZIDE"},{"drugId":"CHEMBL221959","prefName":"TOFACITINIB"},{"drugId":"CHEMBL425","prefName":"OLSALAZINE"}]}}}]}}}
# query generated_query {
#   search(queryString: "fasudil", entityNames: "drug", page: {index: 0, size: 1}) {
#     hits {
#       id
#       name
#       entity
#       object {
#         ... on Drug {
#           linkedTargets {
#             rows {
#               approvedSymbol
#               ... on Target {
#                 associatedDiseases {
#                   rows {
#                     score
#                     disease {
#                       id
#                       name
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }
# {"data":{"search":{"hits":[{"id":"CHEMBL38380","name":"FASUDIL","entity":"drug","object":{"linkedTargets":{"rows":[{"approvedSymbol":"ROCK2","associatedDiseases":{"rows":[{"score":0.5580112081648932,"disease":{"id":"EFO_0004190","name":"open-angle glaucoma"}},{"score":0.5570338462445541,"disease":{"id":"EFO_1001069","name":"ocular hypertension"}},{"score":0.5478429832481734,"disease":{"id":"EFO_0005772","name":"neurodegenerative disease"}},{"score":0.5052279849309224,"disease":{"id":"MONDO_0005041","name":"glaucoma"}},{"score":0.4715736284706049,"disease":{"id":"MONDO_0013730","name":"graft versus host disease"}},{"score":0.46605046286448354,"disease":{"id":"Orphanet_98974","name":"Fuchs endothelial corneal dystrophy"}},{"score":0.40047013678235266,"disease":{"id":"EFO_0004526","name":"mean corpuscular volume"}},{"score":0.3761867338373383,"disease":{"id":"EFO_0004587","name":"lymphocyte count"}},{"score":0.37367454435923936,"disease":{"id":"EFO_0004339","name":"body height"}},{"score":0.3720764692641677,"disease":{"id":"EFO_0000612","name":"myocardial infarction"}},{"score":0.3695798546847018,"disease":{"id":"EFO_1001022","name":"low tension glaucoma"}},{"score":0.3695798546847018,"disease":{"id":"EFO_0000540","name":"immune system disease"}},{"score":0.34449779007508613,"disease":{"id":"EFO_0007788","name":"BMI-adjusted waist-hip ratio"}},{"score":0.32747009105961955,"disease":{"id":"EFO_0007800","name":"body fat percentage"}},{"score":0.32464439018738533,"disease":{"id":"EFO_0007984","name":"platelet component distribution width"}},{"score":0.3201710930473081,"disease":{"id":"EFO_0010701","name":"mean reticulocyte volume"}},{"score":0.31328473619297864,"disease":{"id":"EFO_0004464","name":"brain measurement"}},{"score":0.31282878665806985,"disease":{"id":"EFO_0004840","name":"cortical thickness"}},{"score":0.29525093859405127,"disease":{"id":"EFO_0004532","name":"serum gamma-glutamyl transferase measurement"}},{"score":0.27755447086821106,"disease":{"id":"EFO_0000319","name":"cardiovascular disease"}},{"score":0.27718489101352634,"disease":{"id":"EFO_1000879","name":"corneal edema"}},{"score":0.26644582337094425,"disease":{"id":"EFO_0004980","name":"appendicular lean mass"}},{"score":0.2660512016698931,"disease":{"id":"EFO_0004611","name":"low density lipoprotein cholesterol measurement"}},{"score":0.2658871320913831,"disease":{"id":"EFO_0004193","name":"basal cell carcinoma"}},{"score":0.262697269669774,"disease":{"id":"EFO_0004518","name":"creatinine measurement"}}]}},{"approvedSymbol":"ROCK1","associatedDiseases":{"rows":[{"score":0.5589710891763661,"disease":{"id":"EFO_0004190","name":"open-angle glaucoma"}},{"score":0.5577730059539234,"disease":{"id":"EFO_1001069","name":"ocular hypertension"}},{"score":0.5541525010625129,"disease":{"id":"EFO_0005772","name":"neurodegenerative disease"}},{"score":0.5042300153029697,"disease":{"id":"MONDO_0005041","name":"glaucoma"}},{"score":0.4701877040155372,"disease":{"id":"MONDO_0013730","name":"graft versus host disease"}},{"score":0.46605046286448354,"disease":{"id":"Orphanet_98974","name":"Fuchs endothelial corneal dystrophy"}},{"score":0.37207215435651053,"disease":{"id":"EFO_0000612","name":"myocardial infarction"}},{"score":0.3695798546847018,"disease":{"id":"EFO_0000540","name":"immune system disease"}},{"score":0.3695798546847018,"disease":{"id":"EFO_1001022","name":"low tension glaucoma"}},{"score":0.27907385471524815,"disease":{"id":"EFO_0000319","name":"cardiovascular disease"}},{"score":0.27718489101352634,"disease":{"id":"EFO_1000879","name":"corneal edema"}},{"score":0.2732051836250793,"disease":{"id":"EFO_0000304","name":"breast adenocarcinoma"}},{"score":0.26045228777127727,"disease":{"id":"EFO_0000519","name":"glioblastoma multiforme"}},{"score":0.25870589827929125,"disease":{"id":"EFO_0001071","name":"lung carcinoma"}},{"score":0.25870589827929125,"disease":{"id":"EFO_0003869","name":"breast neoplasm"}},{"score":0.2414183098078613,"disease":{"id":"MONDO_0011962"," ...
# query generated_query {
#   search(queryString: "breast cancer", entityNames: "disease", page: {index: 0, size: 1}) {
#     hits {
#       id
#       name
#       object {
#         ... on Disease {
#           associatedTargets {
#             rows {
#               target {
#                 id
#                 approvedSymbol
#                 pathways {
#                   pathwayId
#                   pathway
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }
# {"data":{"search":{"hits":[{"id":"MONDO_0007254","name":"breast cancer","object":{"associatedTargets":{"rows":[{"target":{"id":"ENSG00000139618","approvedSymbol":"BRCA2","pathways":[{"pathwayId":"R-HSA-5693568","pathway":"Resolution of D-loop Structures through Holliday Junction Intermediates"},{"pathwayId":"R-HSA-5693579","pathway":"Homologous DNA Pairing and Strand Exchange"},{"pathwayId":"R-HSA-5693616","pathway":"Presynaptic phase of homologous DNA pairing and strand exchange"},{"pathwayId":"R-HSA-9704646","pathway":"Defective HDR through Homologous Recombination Repair (HRR) due to PALB2 loss of BRCA2/RAD51/RAD51C binding function"},{"pathwayId":"R-HSA-9709570","pathway":"Impaired BRCA2 binding to RAD51"},{"pathwayId":"R-HSA-9763198","pathway":"Impaired BRCA2 binding to SEM1 (DSS1)"},{"pathwayId":"R-HSA-5693554","pathway":"Resolution of D-loop Structures through Synthesis-Dependent Strand Annealing (SDSA)"},{"pathwayId":"R-HSA-912446","pathway":"Meiotic recombination"},{"pathwayId":"R-HSA-5685939","pathway":"HDR through MMEJ (alt-NHEJ)"},{"pathwayId":"R-HSA-9709603","pathway":"Impaired BRCA2 binding to PALB2"},{"pathwayId":"R-HSA-5685942","pathway":"HDR through Homologous Recombination (HRR)"},{"pathwayId":"R-HSA-9701192","pathway":"Defective homologous recombination repair (HRR) due to BRCA1 loss of function"},{"pathwayId":"R-HSA-9709275","pathway":"Impaired BRCA2 translocation to the nucleus"},{"pathwayId":"R-HSA-9704331","pathway":"Defective HDR through Homologous Recombination Repair (HRR) due to PALB2 loss of BRCA1 binding function"}]}},{"target":{"id":"ENSG00000012048","approvedSymbol":"BRCA1","pathways":[{"pathwayId":"R-HSA-5693568","pathway":"Resolution of D-loop Structures through Holliday Junction Intermediates"},{"pathwayId":"R-HSA-5693579","pathway":"Homologous DNA Pairing and Strand Exchange"},{"pathwayId":"R-HSA-5693616","pathway":"Presynaptic phase of homologous DNA pairing and strand exchange"},{"pathwayId":"R-HSA-9704646","pathway":"Defective HDR through Homologous Recombination Repair (HRR) due to PALB2 loss of BRCA2/RAD51/RAD51C binding function"},{"pathwayId":"R-HSA-6804756","pathway":"Regulation of TP53 Activity through Phosphorylation"},{"pathwayId":"R-HSA-9663199","pathway":"Defective DNA double strand break response due to BRCA1 loss of function"},{"pathwayId":"R-HSA-6796648","pathway":"TP53 Regulates Transcription of DNA Repair Genes"},{"pathwayId":"R-HSA-9709570","pathway":"Impaired BRCA2 binding to RAD51"},{"pathwayId":"R-HSA-5693607","pathway":"Processing of DNA double-strand break ends"},{"pathwayId":"R-HSA-5689901","pathway":"Metalloprotease DUBs"},{"pathwayId":"R-HSA-9755511","pathway":"KEAP1-NFE2L2 pathway"},{"pathwayId":"R-HSA-5693554","pathway":"Resolution of D-loop Structures through Synthesis-Dependent Strand Annealing (SDSA)"},{"pathwayId":"R-HSA-8953750","pathway":"Transcriptional Regulation by E2F6"},{"pathwayId":"R-HSA-69473","pathway":"G2/M DNA damage checkpoint"},{"pathwayId":"R-HSA-5693571","pathway":"Nonhomologous End-Joining (NHEJ)"},{"pathwayId":"R-HSA-1221632","pathway":"Meiotic synapsis"},{"pathwayId":"R-HSA-912446","pathway":"Meiotic recombination"},{"pathwayId":"R-HSA-3108214","pathway":"SUMOylation of DNA damage response and repair proteins"},{"pathwayId":"R-HSA-9699150","pathway":"Defective DNA double strand break response due to BARD1 loss of function"},{"pathwayId":"R-HSA-8951664","pathway":"Neddylation"},{"pathwayId":"R-HSA-9709603","pathway":"Impaired BRCA2 binding to PALB2"},{"pathwayId":"R-HSA-5693565","pathway":"Recruitment and ATM-mediated phosphorylation of repair and signaling proteins at DNA double strand breaks"},{"pathwayId":"R-HSA-5685942","pathway":"HDR through Homologous Recombination (HRR)"},{"pathwayId":"R-HSA-5685938","pathway":"HDR through Single Strand Annealing (SSA)"},{"pathwayId":"R-HSA-9701192","pathway":"Defective homologous recombination repair (HRR) due to BRCA1 loss of function"},{"pathwayId":"R-HSA-9704331","pathway":"Defective HDR through H ...
# query generated_query {
#   search(queryString: "BRCA1", entityNames: "target", page: {index: 0, size: 1}) {
#     hits {
#       id
#       name
#       entity
#       object {
#         ... on Target {
#           associatedDiseases(page: { index: 0, size: 2 }) {
#             rows {
#               score
#               disease {
#                 name
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }
# {"data":{"search":{"hits":[{"id":"ENSG00000012048","name":"BRCA1","entity":"target","object":{"associatedDiseases":{"rows":[{"score":0.8340889978861029,"disease":{"name":"breast-ovarian cancer, familial, susceptibility to, 1"}},{"score":0.8247032876834987,"disease":{"name":"Hereditary breast and ovarian cancer syndrome"}}]}}}]}}}
# query generated_query {
#   search(queryString: "Alzheimer's", entityNames: "disease", page: {index: 0, size: 1}) {
#     hits {
#       id
#       name
#       object {
#         ... on Disease {
#           associatedTargets {
#             rows {
#               target {
#                 id
#                 approvedSymbol
#                 pathways(page: {index: 0, size: 5}) {
#                   rows {
#                     pathway {
#                       id
#                       name
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }
# None
# 400 Client Error: Bad Request for url: https://api.platform.opentargets.org/api/v4/graphql
# {"data":null,"errors":[{"message":"Unknown argument 'page' on field 'pathways' of type 'Target'. (line 13, column 26):\n                pathways(page: {index: 0, size: 5}) {\n                         ^","locations":[{"line":13,"column":26}]},{"message":"Cannot query field 'rows' on type 'ReactomePathway'. (line 14, column 19):\n                  rows {\n                  ^","locations":[{"line":14,"column":19}]}]}

# %%
print(sum([x is None for x in test_query_results]), "error")
# Out:
# 1 error
